# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('weight_vs_height_data.csv')

# %%
df.head()
# Out:
#    Height(cm)  Weight(kg)
# 0  176.797875  135.868971
# 1  163.807644  130.073183
# 2  177.372083  136.700322
# 3  168.184915  129.108693
# 4  180.944991  148.628147

# %%
plt.scatter(df['Height(cm)'], df['Weight(kg)'])
plt.xlabel('Height(cm)')
plt.ylabel('Weight(kg)')
# Out:
# Text(0, 0.5, 'Weight(kg)')

# %%
df.corr()
# Out:
#             Height(cm)  Weight(kg)
# Height(cm)    1.000000    0.718872
# Weight(kg)    0.718872    1.000000

# %%
import seaborn as sns
sns.pairplot(df)

# %%
x = df[['Height(cm)']]
y = df['Weight(kg)']

# %%
x_series = df['Height(cm)']

# %%
y
# Out:
# 0      135.868971
# 1      130.073183
# 2      136.700322
# 3      129.108693
# 4      148.628147
#           ...
# 995    137.714131
# 996    141.761244
# 997    120.790417
# 998    135.667288
# 999    142.693367
# Name: Weight(kg), Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# np.float64(135.07513577912076)

# %%
model.coef_
# Out:
# array([5.41786254])

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train, model.predict(x_train), color = 'red')
